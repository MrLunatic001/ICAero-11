# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

# Define the Neural Network Model with Dropout to avoid overfitting
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        
        # Define layers: 9 input features, 3 hidden layers, 1 output
        self.fc1 = nn.Linear(9, 64)  # First hidden layer: 9 inputs, 64 hidden units
        self.fc2 = nn.Linear(64, 128)  # Second hidden layer: 64 inputs, 128 hidden units
        self.fc3 = nn.Linear(128, 64)  # Third hidden layer: 128 inputs, 64 hidden units
        self.output = nn.Linear(64, 1)  # Output layer: 64 inputs, 1 output
        
        # Activation function
        self.relu = nn.ReLU()

        # Dropout layers to avoid overfitting
        self.dropout = nn.Dropout(p=0.3)

    def forward(self, x):
        # Define forward pass with dropout
        x = self.relu(self.fc1(x))  # First hidden layer + activation
        x = self.dropout(x)  # Dropout after first hidden layer
        x = self.relu(self.fc2(x))  # Second hidden layer + activation
        x = self.dropout(x)  # Dropout after second hidden layer
        x = self.relu(self.fc3(x))  # Third hidden layer + activation
        x = self.output(x)  # Output layer
        return x

def train_model(model, train_loader, criterion, optimizer, epochs):
    for epoch in range(epochs):
        model.train()  # Set the model to training mode
        running_loss = 0.0
        for data, target in train_loader:
            data, target = data.float(), target.float()

            # Forward pass
            outputs = model(data)
            loss = criterion(outputs, target)

            # Backward pass and optimization
            optimizer.zero_grad()  # Zero the gradients
            loss.backward()  # Compute gradients
            
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)

            optimizer.step()  # Update weights

            running_loss += loss.item()

        # Print the average loss for this epoch
        print(f"Epoch [{epoch + 1}/{epochs}], Loss: {running_loss / len(train_loader)}")

def evaluate_model(model, test_loader, scaler, lat_test, lon_test):
    model.eval()  # Set the model to evaluation mode

    with torch.no_grad():
        for i, (data, target) in enumerate(test_loader):
            data, target = data.float(), target.float()
            predicted = model(data)

            # Unnormalize the predictions and targets
            predicted_unscaled = scaler.inverse_transform(predicted.numpy())
            target_unscaled = scaler.inverse_transform(target.numpy())

            # Display test cases: latitude, longitude, predicted, and actual label
            for j in range(len(predicted)):
                print(f"Lat: {lat_test[i*len(predicted) + j]}, Long: {lon_test[i*len(predicted) + j]}")
                print(f"Predicted Label: {predicted_unscaled[j][0]:.4f}, Actual Label: {target_unscaled[j][0]:.4f}\n")

def main():
    # Read CSV data from 'TrainingData.csv'
    data = pd.read_csv('TrainingData.csv')

    # Filter rows to include only rows from 2 to 9964 (indexing 1 to 9963)
    data = data.iloc[1:9964]

    # Extracting labels, features, and lat/long (for test case printing)
    labels = data.iloc[:, 0].values  # Labels (first column)
    features = data.iloc[:, 3:12].values  # Features (columns 4 to 12)
    latitudes = data['Latitude'].values
    longitudes = data['Longitude'].values

    # Standardize the features
    feature_scaler = StandardScaler()
    features = feature_scaler.fit_transform(features)

    # Standardize the labels (optional depending on your label range)
    label_scaler = StandardScaler()
    labels = label_scaler.fit_transform(labels.reshape(-1, 1))

    # Convert to torch tensors
    features = torch.tensor(features, dtype=torch.float32)
    labels = torch.tensor(labels, dtype=torch.float32).view(-1, 1)  # Reshape labels to match output

    # Train-Test Split (80% train, 20% test)
    X_train, X_test, y_train, y_test, lat_train, lat_test, lon_train, lon_test = train_test_split(
        features, labels, latitudes, longitudes, test_size=0.2, random_state=42)

    # Create DataLoader for batches
    train_dataset = TensorDataset(X_train, y_train)
    test_dataset = TensorDataset(X_test, y_test)
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

    # Create a model instance
    model = SimpleNN()

    # Adam optimizer with lower learning rate and weight decay
    optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # Mean Squared Error loss
    criterion = nn.MSELoss()

    # Number of training epochs
    epochs = 10

    # Train the model and print loss after each epoch
    train_model(model, train_loader, criterion, optimizer, epochs)

    # Evaluate the model and print test cases
    evaluate_model(model, test_loader, label_scaler, lat_test, lon_test)

if __name__ == '__main__':
    main()
# Out:
# Epoch [1/10], Loss: 0.7763952226638794
# Epoch [2/10], Loss: 0.2096254352927208
# Epoch [3/10], Loss: 0.07884595558047294
# Epoch [4/10], Loss: 0.07255990152060986
# Epoch [5/10], Loss: 0.06450063760578632
# Epoch [6/10], Loss: 0.06017607666552067
# Epoch [7/10], Loss: 0.05735053467750549
# Epoch [8/10], Loss: 0.05312823927402496
# Epoch [9/10], Loss: 0.0521669330894947
# Epoch [10/10], Loss: 0.048508037477731705
# Lat: -23.6217, Long: -70.3776
# Predicted Label: 0.8808, Actual Label: 0.8870
#
# Lat: -3.1673, Long: -41.5521
# Predicted Label: 0.7183, Actual Label: 0.7195
#
# Lat: -10.9001, Long: -42.5801
# Predicted Label: 0.7986, Actual Label: 0.8142
#
# Lat: 46.0234, Long: 124.7347
# Predicted Label: 0.4635, Actual Label: 0.4585
#
# Lat: 43.0243, Long: -108.385
# Predicted Label: 0.7393, Actual Label: 0.7278
#
# Lat: 34.7292, Long: 112.1364
# Predicted Label: 0.5886, Actual Label: 0.5980
#
# Lat: 34.6813, Long: -118.3141
# Predicted Label: 0.5485, Actual Label: 0.5548
#
# Lat: 29.4136, Long: 112.1653
# Predicted Label: 0.5313, Actual Label: 0.5326
#
# Lat: -16.5157, Long: -41.1832
# Predicted Label: 0.5929, Actual Label: 0.6058
#
# Lat: 41.2629, Long: 114.6577
# Predicted Label: 0.5891, Actual Label: 0.5854
#
# Lat: -4.7532, Long: -37.488
# Predicted Label: 0.7345, Actual Label: 0.7362
#
# Lat: 19.8234, Long: -90.5249
# Predicted Label: 0.6267, Actual Label: 0.6331
#
# Lat: 24.9714, Long: 111.4264
# Predicted Label: 0.5291, Actual Label: 0.5352
#
# Lat: -16.5377, Long: -43.6017
# Predicted Label: 0.7321, Actual Label: 0.7299
#
# Lat: -14.7752, Long: -43.6286
# Predicted Label: 0.7794, Actual Label: 0.7888
#
# Lat: -6.9401, Long: -37.0101
# Predicted Label: 0.7608, Actual Label: 0.7773
#
# Lat: -16.1298, Long: -43.5048
# Predicted Label: 0.7562, Actual Label: 0.7626
#
# Lat: -10.9092, Long: -41.1915
# Predicted Label: 0.7100, Actual Label: 0.7080
#
# Lat: 23.922, Long: 112.1867
# Predicted Label: 0.5294, Actual Label: 0.5306
#
# Lat: -23.8642, Long: -69.128
# Predicted Label: 0.8910, Actual Label: 0.9301
#
# Lat: 31.1244, Long: 114.8936
# Predicted Label: 0.5623, Actual Label: 0.5514
#
# Lat: 25.2793, Long: 112.5588
# Predicted Label: 0.5426, Actual Label: 0.5358
#
# Lat: 24.3681, Long: 113.4941
# Predicted Label: 0.5238, Actual Label: 0.5137
#
# Lat: -16.1426, Long: -43.5198
# Predicted Label: 0.7506, Actual Label: 0.7549
#
# Lat: -8.7058, Long: -41.7403
# Predicted Label: 0.7118, Actual Label: 0.7089
#
# Lat: 39.4935, Long: -85.8191
# Predicted Label: 0.5496, Actual Label: 0.5673
#
# Lat: 34.1265, Long: -116.321
# Predicted Label: 0.7161, Actual Label: 0.7051
#
# Lat: 31.3402, Long: 114.0671
# Predicted Label: 0.5820, Actual Label: 0.5851
#
# Lat: 29.0538, Long: -111.0394
# Predicted Label: 0.7514, Actual Label: 0.7665
#
# Lat: 21.4264, Long: -158.0338
# Predicted Label: 0.3126, Actual Label: 0.3221
#
# Lat: 40.184, Long: -103.639
# Predicted Label: 0.4372, Actual Label: 0.4111
#
# Lat: 38.2471, Long: -77.7862
# Predicted Label: 0.2320, Actual Label: 0.1943
#
# Lat: 37.5109, Long: 116.1474
# Predicted Label: 0.6035, Actual Label: 0.6052
#
# Lat: -17.6212, Long: -71.2699
# Predicted Label: 0.7307, Actual Label: 0.7386
#
# Lat: 29.5545, Long: 110.6851
# Predicted Label: 0.5364, Actual Label: 0.5274
#
# Lat: 35.7049, Long: 114.1254
# Predicted Label: 0.6125, Actual Label: 0.6116
#
# Lat: 28.9053, Long: -96.9781
# Predicted Label: 0.6347, Actual Label: 0.6386
#
# Lat: 8.6171, Long: -73.8017
# Predicted Label: 0.6146, Actual Label: 0.6291
#
# Lat: 36.1992, Long: 114.1612
# Predicted Label: 0.6253, Actual Label: 0.6316
#
# Lat: -5.5201, Long: -37.0701
# Predicted Label: 0.8037, Actual Label: 0.8220
#
# Lat: 39.4564, Long: -77.9663
# Predicted Label: 0.4566, Actual Label: 0.4228
#
# Lat: 40.046, Long: -86.4651
# Predicted Label: 0.4929, Actual Label: 0.4687
#
# Lat: 41.642, Long: -72.049
# Predicted Label: 0.5774, Actual Label: 0.6040
#
# Lat: -15.37, Long: -44.6842
# Predicted Label: 0.6860, Actual Label: 0.6742
#
# Lat: 40.6595, Long: -83.8137
# Predicted Label: 0.4834, Actual Label: 0.4829
#
# Lat: 32.8757, Long: -111.5511
# Predicted Label: 0.7756, Actual Label: 0.7741
#
# Lat: 32.5861, Long: -84.3352
# Predicted Label: 0.7565, Actual Label: 0.7640
#
# Lat: -10.0916, Long: -45.2644
# Predicted Label: 0.7660, Actual Label: 0.7740
#
# Lat: 23.321, Long: 109.815
# Predicted Label: 0.5546, Actual Label: 0.5547
#
# Lat: -22.9935, Long: 29.2501
# Predicted Label: 0.7402, Actual Label: 0.7607
#
# Lat: 23.1783, Long: 114.4586
# Predicted Label: 0.5936, Actual Label: 0.5995
#
# Lat: -15.9601, Long: -43.3701
# Predicted Label: 0.7243, Actual Label: 0.7266
#
# Lat: 48.0001, Long: 128.0001
# Predicted Label: 0.4641, Actual Label: 0.4611
#
# Lat: 42.1266, Long: 77.5306
# Predicted Label: 0.7082, Actual Label: 0.6740
#
# Lat: 26.0917, Long: 105.6098
# Predicted Label: 0.5319, Actual Label: 0.5295
#
# Lat: -33.0195, Long: 18.0939
# Predicted Label: 0.7668, Actual Label: 0.7743
#
# Lat: 38.9443, Long: -74.882
# Predicted Label: 0.6713, Actual Label: 0.6583
#
# Lat: 38.981, Long: 102.5198
# Predicted Label: 0.7560, Actual Label: 0.7512
#
# Lat: 20.43, Long: -98.8539
# Predicted Label: 0.7662, Actual Label: 0.7605
#
# Lat: 35.8894, Long: -114.9579
# Predicted Label: 0.7942, Actual Label: 0.7918
#
# Lat: -27.119, Long: -70.1715
# Predicted Label: 0.8680, Actual Label: 0.8992
#
# Lat: -9.7054, Long: -40.6985
# Predicted Label: 0.7517, Actual Label: 0.7579
#
# Lat: 27.6646, Long: -81.9642
# Predicted Label: 0.7453, Actual Label: 0.7427
#
# Lat: 40.7069, Long: 114.4705
# Predicted Label: 0.6423, Actual Label: 0.6394
#
# Lat: -12.4684, Long: 13.7437
# Predicted Label: 0.7267, Actual Label: 0.7242
#
# Lat: 29.8337, Long: 113.4778
# Predicted Label: 0.5443, Actual Label: 0.5405
#
# Lat: -16.7844, Long: -42.2189
# Predicted Label: 0.6557, Actual Label: 0.6529
#
# Lat: 18.3442, Long: -71.1249
# Predicted Label: 0.6275, Actual Label: 0.6317
#
# Lat: 29.9138, Long: -110.8643
# Predicted Label: 0.7763, Actual Label: 0.7870
#
# Lat: 25.768, Long: 105.498
# Predicted Label: 0.5538, Actual Label: 0.5600
#
# Lat: -18.9158, Long: -49.3361
# Predicted Label: 0.7094, Actual Label: 0.7082
#
# Lat: 38.2654, Long: -77.3142
# Predicted Label: 0.5347, Actual Label: 0.5456
#
# Lat: 10.8814, Long: -0.559
# Predicted Label: 0.7808, Actual Label: 0.8041
#
# Lat: -15.301, Long: -43.582
# Predicted Label: 0.6318, Actual Label: 0.6604
#
# Lat: 33.3689, Long: -81.365
# Predicted Label: 0.5400, Actual Label: 0.5518
#
# Lat: 34.5394, Long: -78.7554
# Predicted Label: 0.7812, Actual Label: 0.7854
#
# Lat: -17.4974, Long: -44.8179
# Predicted Label: 0.7347, Actual Label: 0.7360
#
# Lat: -14.9124, Long: -43.6091
# Predicted Label: 0.7821, Actual Label: 0.7907
#
# Lat: 33.8753, Long: -113.9377
# Predicted Label: 0.5517, Actual Label: 0.5587
#
# Lat: 23.37, Long: 111.0017
# Predicted Label: 0.5621, Actual Label: 0.5584
#
# Lat: 34.8476, Long: -78.8774
# Predicted Label: 0.7208, Actual Label: 0.7100
#
# Lat: -19.6854, Long: -51.3858
# Predicted Label: 0.7203, Actual Label: 0.7172
#
# Lat: 22.7208, Long: 111.4168
# Predicted Label: 0.5553, Actual Label: 0.5505
#
# Lat: 34.1001, Long: 113.0918
# Predicted Label: 0.6380, Actual Label: 0.6402
#
# Lat: 31.5723, Long: 118.4928
# Predicted Label: 0.5416, Actual Label: 0.5387
#
# Lat: -9.7021, Long: -40.6713
# Predicted Label: 0.7355, Actual Label: 0.7392
#
# Lat: -15.7347, Long: -45.9831
# Predicted Label: 0.7502, Actual Label: 0.7527
#
# Lat: 42.7892, Long: 73.6806
# Predicted Label: 0.6937, Actual Label: 0.6710
#
# Lat: 16.6272, Long: -98.6366
# Predicted Label: 0.7189, Actual Label: 0.7209
#
# Lat: 38.7776, Long: 114.3318
# Predicted Label: 0.6331, Actual Label: 0.6337
#
# Lat: 21.3152, Long: 109.9328
# Predicted Label: 0.5535, Actual Label: 0.5507
#
# Lat: 48.0001, Long: 128.0001
# Predicted Label: 0.4641, Actual Label: 0.4626
#
# Lat: 41.2061, Long: 116.6456
# Predicted Label: 0.6009, Actual Label: 0.6040
#
# Lat: -19.5585, Long: -53.5396
# Predicted Label: 0.7170, Actual Label: 0.7203
#
# Lat: 38.1434, Long: 117.4952
# Predicted Label: 0.6129, Actual Label: 0.6163
#
# Lat: 9.1846, Long: -75.3802
# Predicted Label: 0.6134, Actual Label: 0.6205
#
# Lat: 40.0556, Long: -85.1266
# Predicted Label: 0.4783, Actual Label: 0.4720
#
# Lat: -11.7717, Long: -42.1864
# Predicted Label: 0.6858, Actual Label: 0.6766
#
# Lat: -5.3156, Long: -39.5744
# Predicted Label: 0.6772, Actual Label: 0.6692
#
# Lat: 39.9189, Long: 114.8313
# Predicted Label: 0.5936, Actual Label: 0.6114
#
# Lat: -15.6728, Long: -46.4331
# Predicted Label: 0.7597, Actual Label: 0.7635
#
# Lat: -10.7131, Long: -43.9445
# Predicted Label: 0.7586, Actual Label: 0.7579
#
# Lat: 36.371, Long: -77.571
# Predicted Label: 0.5717, Actual Label: 0.5880
#
# Lat: -9.6767, Long: -40.5244
# Predicted Label: 0.7980, Actual Label: 0.8088
#
# Lat: -18.8401, Long: -52.4301
# Predicted Label: 0.7541, Actual Label: 0.7629
#
# Lat: 48.5229, Long: 126.221
# Predicted Label: 0.4523, Actual Label: 0.4505
#
# Lat: 43.4405, Long: 68.5256
# Predicted Label: 0.7015, Actual Label: 0.6974
#
# Lat: 29.218, Long: -99.705
# Predicted Label: 0.5726, Actual Label: 0.5944
#
# Lat: 46.2909, Long: 123.7283
# Predicted Label: 0.4518, Actual Label: 0.4507
#
# Lat: 2.0777, Long: 45.3389
# Predicted Label: 0.8266, Actual Label: 0.8513
#
# Lat: -17.1132, Long: -45.6864
# Predicted Label: 0.7445, Actual Label: 0.7466
#
# Lat: 22.9173, Long: 115.4248
# Predicted Label: 0.5513, Actual Label: 0.5602
#
# Lat: -5.2529, Long: -38.3745
# Predicted Label: 0.7094, Actual Label: 0.7074
#
# Lat: 30.9676, Long: -97.1651
# Predicted Label: 0.5069, Actual Label: 0.5106
#
# Lat: 37.9714, Long: -84.155
# Predicted Label: 0.4433, Actual Label: 0.4188
#
# Lat: 34.9299, Long: -80.6256
# Predicted Label: 0.5274, Actual Label: 0.5355
#
# Lat: -15.1711, Long: -44.6842
# Predicted Label: 0.7471, Actual Label: 0.7442
#
# Lat: 23.2193, Long: 107.6606
# Predicted Label: 0.5474, Actual Label: 0.5478
#
# Lat: 21.1922, Long: 110.4878
# Predicted Label: 0.6027, Actual Label: 0.6108
#
# Lat: 23.4036, Long: 112.1259
# Predicted Label: 0.5585, Actual Label: 0.5676
#
# Lat: 42.5049, Long: -84.477
# Predicted Label: 0.4776, Actual Label: 0.4950
#
# Lat: 35.354, Long: -106.858
# Predicted Label: 0.7122, Actual Label: 0.6995
#
# Lat: 27.0529, Long: 104.4239
# Predicted Label: 0.5278, Actual Label: 0.5219
#
# Lat: 10.6301, Long: -61.4087
# Predicted Label: 0.6402, Actual Label: 0.6407
#
# Lat: 39.5289, Long: 119.0823
# Predicted Label: 0.5950, Actual Label: 0.6011
#
# Lat: -17.5439, Long: -71.0305
# Predicted Label: 0.8274, Actual Label: 0.8441
#
# Lat: 38.093, Long: 117.421
# Predicted Label: 0.6194, Actual Label: 0.6184
#
# Lat: 25.8723, Long: 105.9385
# Predicted Label: 0.5246, Actual Label: 0.5217
#
# Lat: 7.9579, Long: -1.7473
# Predicted Label: 0.7022, Actual Label: 0.7030
#
# Lat: -4.1266, Long: -41.4455
# Predicted Label: 0.6234, Actual Label: 0.6302
#
# Lat: -5.6132, Long: -36.7326
# Predicted Label: 0.7299, Actual Label: 0.7355
#
# Lat: 24.8503, Long: 105.6097
# Predicted Label: 0.5693, Actual Label: 0.5812
#
# Lat: 38.762, Long: 116.491
# Predicted Label: 0.5990, Actual Label: 0.6026
#
# Lat: 38.9327, Long: 114.8467
# Predicted Label: 0.6162, Actual Label: 0.6097
#
# Lat: 25.5283, Long: -103.2505
# Predicted Label: 0.7681, Actual Label: 0.7795
#
# Lat: -5.5265, Long: -37.444
# Predicted Label: 0.7343, Actual Label: 0.7374
#
# Lat: -7.8636, Long: -38.8322
# Predicted Label: 0.7288, Actual Label: 0.7316
#
# Lat: 6.4721, Long: 7.4398
# Predicted Label: 0.6814, Actual Label: 0.6760
#
# Lat: 34.2737, Long: 112.8329
# Predicted Label: 0.6098, Actual Label: 0.6206
#
# Lat: 22.4674, Long: 108.5769
# Predicted Label: 0.5645, Actual Label: 0.5705
#
# Lat: -22.2595, Long: 20.4389
# Predicted Label: 0.8395, Actual Label: 0.8609
#
# Lat: -18.8402, Long: -52.3986
# Predicted Label: 0.7049, Actual Label: 0.7007
#
# Lat: 24.8046, Long: 104.8019
# Predicted Label: 0.5399, Actual Label: 0.5417
#
# Lat: 38.089, Long: 102.837
# Predicted Label: 0.7641, Actual Label: 0.7703
#
# Lat: -31.3327, Long: -68.6685
# Predicted Label: 0.7656, Actual Label: 0.7643
#
# Lat: 27.0601, Long: -80.4745
# Predicted Label: 0.7754, Actual Label: 0.7781
#
# Lat: 40.8683, Long: -112.7034
# Predicted Label: 0.5786, Actual Label: 0.5938
#
# Lat: 23.0795, Long: 114.3807
# Predicted Label: 0.5720, Actual Label: 0.5757
#
# Lat: 42.7569, Long: -74.4928
# Predicted Label: 0.4722, Actual Label: 0.4653
#
# Lat: 34.8301, Long: -118.32
# Predicted Label: 0.5431, Actual Label: 0.5619
#
# Lat: -6.5757, Long: -40.7778
# Predicted Label: 0.6957, Actual Label: 0.6919
#
# Lat: 28.7395, Long: 112.6883
# Predicted Label: 0.5439, Actual Label: 0.5413
#
# Lat: 8.3078, Long: 1.0103
# Predicted Label: 0.7470, Actual Label: 0.7497
#
# Lat: -7.9648, Long: -38.6307
# Predicted Label: 0.7145, Actual Label: 0.7146
#
# Lat: -24.0915, Long: -66.7248
# Predicted Label: 0.7787, Actual Label: 0.7813
#
# Lat: -6.9465, Long: -43.1526
# Predicted Label: 0.7454, Actual Label: 0.7491
#
# Lat: 36.121, Long: -77.404
# Predicted Label: 0.5461, Actual Label: 0.5526
#
# Lat: -6.3553, Long: -38.9578
# Predicted Label: 0.7353, Actual Label: 0.7423
#
# Lat: 37.6632, Long: -88.9841
# Predicted Label: 0.8137, Actual Label: 0.8128
#
# Lat: 32.2546, Long: 117.1501
# Predicted Label: 0.5870, Actual Label: 0.5910
#
# Lat: 35.1712, Long: -118.0017
# Predicted Label: 0.7899, Actual Label: 0.7966
#
# Lat: 34.4724, Long: -101.712
# Predicted Label: 0.4832, Actual Label: 0.4808
#
# Lat: -13.6511, Long: -45.7124
# Predicted Label: 0.7237, Actual Label: 0.7265
#
# Lat: 24.2351, Long: -104.4641
# Predicted Label: 0.7753, Actual Label: 0.7908
#
# Lat: 29.3752, Long: 113.8766
# Predicted Label: 0.5685, Actual Label: 0.5678
#
# Lat: -16.226, Long: -43.5168
# Predicted Label: 0.7649, Actual Label: 0.7731
#
# Lat: -20.6601, Long: -51.3301
# Predicted Label: 0.6772, Actual Label: 0.6693
#
# Lat: -15.4273, Long: -43.801
# Predicted Label: 0.7666, Actual Label: 0.7716
#
# Lat: 29.7134, Long: 32.3045
# Predicted Label: 0.7365, Actual Label: 0.7476
#
# Lat: 19.6876, Long: 110.3752
# Predicted Label: 0.6584, Actual Label: 0.6575
#
# Lat: 31.889, Long: -100.842
# Predicted Label: 0.6276, Actual Label: 0.6353
#
# Lat: 11.3407, Long: -13.9441
# Predicted Label: 0.7395, Actual Label: 0.7408
#
# Lat: -15.3328, Long: -44.7019
# Predicted Label: 0.7445, Actual Label: 0.7438
#
# Lat: 34.468, Long: 116.202
# Predicted Label: 0.5557, Actual Label: 0.5623
#
# Lat: 26.6945, Long: 112.5045
# Predicted Label: 0.5508, Actual Label: 0.5552
#
# Lat: 34.6783, Long: -118.3026
# Predicted Label: 0.6810, Actual Label: 0.6683
#
# Lat: -20.104, Long: -51.4278
# Predicted Label: 0.7173, Actual Label: 0.7105
#
# Lat: -28.5707, Long: 21.0613
# Predicted Label: 0.8153, Actual Label: 0.8395
#
# Lat: 38.3118, Long: 114.5651
# Predicted Label: 0.5642, Actual Label: 0.5794
#
# Lat: 32.0001, Long: 117.0001
# Predicted Label: 0.5776, Actual Label: 0.5879
#
# Lat: -10.7759, Long: -41.2645
# Predicted Label: 0.7135, Actual Label: 0.7119
#
# Lat: 38.4776, Long: 114.238
# Predicted Label: 0.6398, Actual Label: 0.6406
#
# Lat: 46.6527, Long: 126.9714
# Predicted Label: 0.4015, Actual Label: 0.4264
#
# Lat: -8.2665, Long: -42.3276
# Predicted Label: 0.7117, Actual Label: 0.7073
#
# Lat: -13.1126, Long: 30.4022
# Predicted Label: 0.7209, Actual Label: 0.7262
#
# Lat: 5.3413, Long: -0.7024
# Predicted Label: 0.7541, Actual Label: 0.7552
#
# Lat: -5.4697, Long: -38.8325
# Predicted Label: 0.7409, Actual Label: 0.7484
#
# Lat: 39.4286, Long: 93.8931
# Predicted Label: 0.7477, Actual Label: 0.7386
#
# Lat: -16.3608, Long: -43.6178
# Predicted Label: 0.7542, Actual Label: 0.7602
#
# Lat: 51.6323, Long: -111.9127
# Predicted Label: 0.3519, Actual Label: 0.3494
#
# Lat: 31.0028, Long: -112.6221
# Predicted Label: 0.8254, Actual Label: 0.8405
#
# Lat: 33.2689, Long: -100.6269
# Predicted Label: 0.7179, Actual Label: 0.7132
#
# Lat: 34.045, Long: 113.277
# Predicted Label: 0.6217, Actual Label: 0.6257
#
# Lat: -14.4285, Long: 28.4352
# Predicted Label: 0.7389, Actual Label: 0.7517
#
# Lat: -3.6983, Long: -41.5914
# Predicted Label: 0.7269, Actual Label: 0.7306
#
# Lat: 33.8231, Long: -115.3939
# Predicted Label: 0.8304, Actual Label: 0.8412
#
# Lat: -9.8567, Long: -40.5519
# Predicted Label: 0.7353, Actual Label: 0.7366
#
# Lat: 11.6815, Long: 9.3858
# Predicted Label: 0.8053, Actual Label: 0.8269
#
# Lat: 21.573, Long: 111.521
# Predicted Label: 0.5986, Actual Label: 0.6014
#
# Lat: -19.1564, Long: 33.1443
# Predicted Label: 0.6947, Actual Label: 0.6868
#
# Lat: 29.0903, Long: -110.987
# Predicted Label: 0.7763, Actual Label: 0.7870
#
# Lat: 27.4633, Long: 113.4124
# Predicted Label: 0.5575, Actual Label: 0.5601
#
# Lat: 26.823, Long: 111.6976
# Predicted Label: 0.5618, Actual Label: 0.5590
#
# Lat: 24.4937, Long: 117.944
# Predicted Label: 0.5909, Actual Label: 0.6010
#
# Lat: -15.1429, Long: -44.6965
# Predicted Label: 0.7462, Actual Label: 0.7434
#
# Lat: 32.6681, Long: -115.6055
# Predicted Label: 0.6545, Actual Label: 0.6503
#
# Lat: -17.3005, Long: -44.8857
# Predicted Label: 0.7460, Actual Label: 0.7445
#
# Lat: -4.7999, Long: -37.4698
# Predicted Label: 0.7274, Actual Label: 0.7258
#
# Lat: -4.7179, Long: -37.4978
# Predicted Label: 0.7304, Actual Label: 0.7306
#
# Lat: 29.8979, Long: 114.2405
# Predicted Label: 0.5744, Actual Label: 0.5782
#
# Lat: 40.1188, Long: 94.493
# Predicted Label: 0.7844, Actual Label: 0.7865
#
# Lat: 29.8336, Long: 115.117
# Predicted Label: 0.5355, Actual Label: 0.5298
#
# Lat: 35.233, Long: -91.69
# Predicted Label: 0.7973, Actual Label: 0.7849
#
# Lat: 26.404, Long: 112.9341
# Predicted Label: 0.5542, Actual Label: 0.5598
#
# Lat: 43.2874, Long: 68.2738
# Predicted Label: 0.6412, Actual Label: 0.6376
#
# Lat: 32.7471, Long: 116.92
# Predicted Label: 0.5940, Actual Label: 0.5983
#
# Lat: -16.6767, Long: -49.7016
# Predicted Label: 0.7189, Actual Label: 0.7183
#
# Lat: -6.6303, Long: -38.8528
# Predicted Label: 0.7466, Actual Label: 0.7557
#
# Lat: 32.2309, Long: 113.2785
# Predicted Label: 0.5754, Actual Label: 0.5807
#
# Lat: 8.017, Long: -80.5091
# Predicted Label: 0.6900, Actual Label: 0.6843
#
# Lat: 30.4274, Long: 115.0275
# Predicted Label: 0.5591, Actual Label: 0.5559
#
# Lat: 38.5814, Long: 102.1368
# Predicted Label: 0.7480, Actual Label: 0.7434
#
# Lat: -13.3227, Long: -43.354
# Predicted Label: 0.7363, Actual Label: 0.7440
#
# Lat: -7.9908, Long: -38.5698
# Predicted Label: 0.7057, Actual Label: 0.6985
#
# Lat: 26.5989, Long: 111.7028
# Predicted Label: 0.5545, Actual Label: 0.5440
#
# Lat: -8.8481, Long: -44.1656
# Predicted Label: 0.7481, Actual Label: 0.7510
#
# Lat: 39.8029, Long: 98.1701
# Predicted Label: 0.7898, Actual Label: 0.7748
#
# Lat: 50.0309, Long: -113.481
# Predicted Label: 0.4468, Actual Label: 0.4576
#
# Lat: -20.1047, Long: -69.4841
# Predicted Label: 0.6463, Actual Label: 0.6355
#
# Lat: 27.1565, Long: 104.7632
# Predicted Label: 0.5430, Actual Label: 0.5453
#
# Lat: -15.9493, Long: -43.5274
# Predicted Label: 0.7462, Actual Label: 0.7517
#
# Lat: -3.3147, Long: -39.394
# Predicted Label: 0.7260, Actual Label: 0.7311
#
# Lat: -17.586, Long: -43.7578
# Predicted Label: 0.6502, Actual Label: 0.6536
#
# Lat: 31.5215, Long: -96.6739
# Predicted Label: 0.7087, Actual Label: 0.6959
#
# Lat: 41.311, Long: 114.249
# Predicted Label: 0.6059, Actual Label: 0.6155
#
# Lat: 39.5724, Long: -77.3079
# Predicted Label: 0.5636, Actual Label: 0.5775
#
# Lat: -7.5489, Long: -37.2614
# Predicted Label: 0.7291, Actual Label: 0.7362
#
# Lat: 30.862, Long: -83.6517
# Predicted Label: 0.5000, Actual Label: 0.4995
#
# Lat: -15.2743, Long: -56.2264
# Predicted Label: 0.7447, Actual Label: 0.7507
#
# Lat: 32.506, Long: -84.257
# Predicted Label: 0.5529, Actual Label: 0.5634
#
# Lat: 10.8891, Long: -74.9774
# Predicted Label: 0.5781, Actual Label: 0.6006
#
# Lat: 31.7844, Long: 112.0322
# Predicted Label: 0.5813, Actual Label: 0.5834
#
# Lat: 22.763, Long: -102.5818
# Predicted Label: 0.7897, Actual Label: 0.7932
#
# Lat: 44.6378, Long: -69.5031
# Predicted Label: 0.4305, Actual Label: 0.3980
#
# Lat: 31.4438, Long: 118.7247
# Predicted Label: 0.6053, Actual Label: 0.6064
#
# Lat: 5.3728, Long: -0.6933
# Predicted Label: 0.7560, Actual Label: 0.7748
#
# Lat: 12.3089, Long: -86.0543
# Predicted Label: 0.6831, Actual Label: 0.6817
#
# Lat: 34.8344, Long: -78.8436
# Predicted Label: 0.5773, Actual Label: 0.5918
#
# Lat: 13.078, Long: -11.395
# Predicted Label: 0.7846, Actual Label: 0.8146
#
# Lat: 21.3403, Long: -158.0151
# Predicted Label: 0.5552, Actual Label: 0.5598
#
# Lat: -15.2819, Long: -56.2462
# Predicted Label: 0.7114, Actual Label: 0.7115
#
# Lat: -15.8075, Long: -43.4832
# Predicted Label: 0.7615, Actual Label: 0.7679
#
# Lat: 30.8198, Long: -92.9718
# Predicted Label: 0.5061, Actual Label: 0.5097
#
# Lat: 21.639, Long: 108.795
# Predicted Label: 0.5749, Actual Label: 0.5745
#
# Lat: 38.721, Long: 114.658
# Predicted Label: 0.6209, Actual Label: 0.6223
#
# Lat: 25.1207, Long: 114.3068
# Predicted Label: 0.5595, Actual Label: 0.5696
#
# Lat: 38.123, Long: 102.839
# Predicted Label: 0.7655, Actual Label: 0.7725
#
# Lat: 0.4129, Long: 35.4011
# Predicted Label: 0.7796, Actual Label: 0.8072
#
# Lat: 23.872, Long: 115.755
# Predicted Label: 0.5600, Actual Label: 0.5564
#
# Lat: -20.3003, Long: 57.5507
# Predicted Label: 0.6825, Actual Label: 0.6786
#
# Lat: 39.926, Long: 118.5028
# Predicted Label: 0.6369, Actual Label: 0.6365
#
# Lat: 41.7967, Long: 116.3386
# Predicted Label: 0.5854, Actual Label: 0.5713
#
# Lat: -12.7799, Long: -45.8114
# Predicted Label: 0.7550, Actual Label: 0.7555
#
# Lat: -10.6869, Long: -44.6894
# Predicted Label: 0.7437, Actual Label: 0.7446
#
# Lat: -5.8101, Long: -36.6401
# Predicted Label: 0.7514, Actual Label: 0.7520
#
# Lat: 34.292, Long: 112.4292
# Predicted Label: 0.6104, Actual Label: 0.6133
#
# Lat: 19.0371, Long: -98.2012
# Predicted Label: 0.6970, Actual Label: 0.7077
#
# Lat: 36.5901, Long: -77.65
# Predicted Label: 0.5024, Actual Label: 0.5007
#
# Lat: -15.3591, Long: -43.8072
# Predicted Label: 0.7785, Actual Label: 0.7883
#
# Lat: 49.2875, Long: -113.1599
# Predicted Label: 0.3454, Actual Label: 0.3493
#
# Lat: 31.2403, Long: 118.5268
# Predicted Label: 0.5716, Actual Label: 0.5620
#
# Lat: 36.3079, Long: -76.1445
# Predicted Label: 0.7714, Actual Label: 0.7765
#
# Lat: 33.5974, Long: 114.3807
# Predicted Label: 0.6056, Actual Label: 0.6134
#
# Lat: 21.4279, Long: -158.0199
# Predicted Label: 0.7882, Actual Label: 0.7978
#
# Lat: 23.2305, Long: 114.6083
# Predicted Label: 0.5951, Actual Label: 0.6055
#
# Lat: 25.7698, Long: 106.9776
# Predicted Label: 0.4835, Actual Label: 0.4532
#
# Lat: 11.4354, Long: -72.9002
# Predicted Label: 0.6835, Actual Label: 0.6931
#
# Lat: -17.623, Long: -44.9138
# Predicted Label: 0.7385, Actual Label: 0.7357
#
# Lat: -16.822, Long: -70.6893
# Predicted Label: 0.8885, Actual Label: 0.8744
#
# Lat: -15.5149, Long: -47.4067
# Predicted Label: 0.7470, Actual Label: 0.7516
#
# Lat: 34.8597, Long: 4.2026
# Predicted Label: 0.8334, Actual Label: 0.8509
#
# Lat: -17.3001, Long: -45.2201
# Predicted Label: 0.7360, Actual Label: 0.7365
#
# Lat: -16.2301, Long: -43.5153
# Predicted Label: 0.7573, Actual Label: 0.7643
#
# Lat: 20.6123, Long: -103.5312
# Predicted Label: 0.7350, Actual Label: 0.7205
#
# Lat: -10.7914, Long: -41.2521
# Predicted Label: 0.7166, Actual Label: 0.7165
#
# Lat: 26.823, Long: 111.6976
# Predicted Label: 0.5619, Actual Label: 0.5704
#
# Lat: -23.1014, Long: -70.4687
# Predicted Label: 0.8525, Actual Label: 0.8597
#
# Lat: 24.9059, Long: 113.5454
# Predicted Label: 0.5577, Actual Label: 0.5638
#
# Lat: 32.2907, Long: -100.8657
# Predicted Label: 0.4509, Actual Label: 0.4298
#
# Lat: 26.6924, Long: 105.3469
# Predicted Label: 0.4886, Actual Label: 0.4685
#
# Lat: -14.124, Long: -47.5066
# Predicted Label: 0.7304, Actual Label: 0.7353
#
# Lat: 31.2453, Long: -85.087
# Predicted Label: 0.4590, Actual Label: 0.4301
#
# Lat: -22.5472, Long: 17.0842
# Predicted Label: 0.9129, Actual Label: 0.9710
#
# Lat: 39.895, Long: -77.8061
# Predicted Label: 0.7696, Actual Label: 0.7666
#
# Lat: 32.7043, Long: 112.8373
# Predicted Label: 0.5694, Actual Label: 0.5784
#
# Lat: 34.752, Long: -118.315
# Predicted Label: 0.5789, Actual Label: 0.5969
#
# Lat: 18.3081, Long: -66.4093
# Predicted Label: 0.6767, Actual Label: 0.6685
#
# Lat: 38.0678, Long: 115.604
# Predicted Label: 0.6106, Actual Label: 0.6136
#
# Lat: -10.0991, Long: -45.2815
# Predicted Label: 0.7704, Actual Label: 0.7785
#
# Lat: -6.9576, Long: -37.0879
# Predicted Label: 0.7449, Actual Label: 0.7503
#
# Lat: -6.9523, Long: -37.1022
# Predicted Label: 0.7665, Actual Label: 0.7830
#
# Lat: 27.0291, Long: 111.2024
# Predicted Label: 0.5591, Actual Label: 0.5508
#
# Lat: -4.7671, Long: -37.493
# Predicted Label: 0.7396, Actual Label: 0.7443
#
# Lat: 31.0444, Long: -96.8514
# Predicted Label: 0.4956, Actual Label: 0.4956
#
# Lat: 25.3881, Long: 105.3874
# Predicted Label: 0.5581, Actual Label: 0.5727
#
# Lat: -16.5245, Long: -41.1927
# Predicted Label: 0.5974, Actual Label: 0.6119
#
# Lat: 38.4499, Long: 114.7239
# Predicted Label: 0.6303, Actual Label: 0.6267
#
# Lat: 35.3547, Long: -78.6451
# Predicted Label: 0.7853, Actual Label: 0.7936
#
# Lat: 35.292, Long: -81.783
# Predicted Label: 0.7580, Actual Label: 0.7643
#
# Lat: 21.8063, Long: 108.7705
# Predicted Label: 0.5893, Actual Label: 0.5955
#
# Lat: 23.608, Long: 116.0995
# Predicted Label: 0.5813, Actual Label: 0.5894
#
# Lat: -14.7541, Long: -48.7171
# Predicted Label: 0.7243, Actual Label: 0.7266
#
# Lat: 40.8861, Long: 118.2453
# Predicted Label: 0.6116, Actual Label: 0.6247
#
# Lat: 9.2005, Long: 8.4134
# Predicted Label: 0.7652, Actual Label: 0.7854
#
# Lat: -8.7488, Long: -38.3131
# Predicted Label: 0.7319, Actual Label: 0.7339
#
# Lat: 28.315, Long: 109.7341
# Predicted Label: 0.4838, Actual Label: 0.4735
#
# Lat: -23.4939, Long: -69.4187
# Predicted Label: 0.9081, Actual Label: 0.9448
#
# Lat: -15.5794, Long: -46.7228
# Predicted Label: 0.7453, Actual Label: 0.7467
#
# Lat: 8.7409, Long: -74.6457
# Predicted Label: 0.5898, Actual Label: 0.6150
#
# Lat: 30.295, Long: -82.186
# Predicted Label: 0.7767, Actual Label: 0.7730
#
# Lat: 22.099, Long: -102.3201
# Predicted Label: 0.7704, Actual Label: 0.7905
#
# Lat: 34.0001, Long: 114.0001
# Predicted Label: 0.5867, Actual Label: 0.5884
#
# Lat: 36.876, Long: -80.837
# Predicted Label: 0.7550, Actual Label: 0.7586
#
# Lat: 36.551, Long: 107.199
# Predicted Label: 0.6647, Actual Label: 0.6548
#
# Lat: 40.0462, Long: -85.0451
# Predicted Label: 0.4373, Actual Label: 0.4235
#
# Lat: -6.982, Long: -37.3184
# Predicted Label: 0.7468, Actual Label: 0.7592
#
# Lat: -8.0804, Long: -39.3445
# Predicted Label: 0.7452, Actual Label: 0.7501
#
# Lat: 32.9011, Long: -100.9827
# Predicted Label: 0.7204, Actual Label: 0.7133
#
# Lat: 35.3515, Long: -89.8547
# Predicted Label: 0.5462, Actual Label: 0.5574
#
# Lat: 35.0984, Long: -107.6146
# Predicted Label: 0.7626, Actual Label: 0.7522
#
# Lat: 43.0832, Long: -89.3215
# Predicted Label: 0.7811, Actual Label: 0.7867
#
# Lat: 29.6049, Long: 112.3854
# Predicted Label: 0.5690, Actual Label: 0.5655
#
# Lat: 31.5511, Long: 112.9716
# Predicted Label: 0.5975, Actual Label: 0.5973
#
# Lat: 41.941, Long: -84.035
# Predicted Label: 0.4622, Actual Label: 0.4497
#
# Lat: 21.5457, Long: 108.1016
# Predicted Label: 0.3245, Actual Label: 0.2625
#
# Lat: 26.0021, Long: 104.5086
# Predicted Label: 0.5610, Actual Label: 0.5561
#
# Lat: 34.4937, Long: -116.915
# Predicted Label: 0.5127, Actual Label: 0.4995
#
# Lat: 24.5386, Long: 113.5344
# Predicted Label: 0.6149, Actual Label: 0.6203
#
# Lat: 26.3952, Long: 111.3106
# Predicted Label: 0.5518, Actual Label: 0.5389
#
# Lat: 41.2688, Long: 116.4955
# Predicted Label: 0.5905, Actual Label: 0.5997
#
# Lat: 31.1054, Long: 109.6353
# Predicted Label: 0.5437, Actual Label: 0.5386
#
# Lat: 32.6633, Long: -115.6583
# Predicted Label: 0.4684, Actual Label: 0.4545
#
# Lat: 38.1434, Long: 102.7338
# Predicted Label: 0.7140, Actual Label: 0.7049
#
# Lat: -17.9312, Long: 25.8348
# Predicted Label: 0.7489, Actual Label: 0.7602
#
# Lat: -18.798, Long: 29.7986
# Predicted Label: 0.7496, Actual Label: 0.7666
#
# Lat: -3.2961, Long: -41.6376
# Predicted Label: 0.7576, Actual Label: 0.7659
#
# Lat: -19.71, Long: -51.4712
# Predicted Label: 0.7093, Actual Label: 0.7049
#
# Lat: 34.4953, Long: -102.259
# Predicted Label: 0.5997, Actual Label: 0.6203
#
# Lat: 23.6438, Long: 109.1871
# Predicted Label: 0.5407, Actual Label: 0.5371
#
# Lat: 31.9421, Long: 117.3799
# Predicted Label: 0.5845, Actual Label: 0.5767
#
# Lat: 32.0001, Long: 117.0001
# Predicted Label: 0.5770, Actual Label: 0.5733
#
# Lat: -7.5701, Long: -37.204
# Predicted Label: 0.7501, Actual Label: 0.7598
#
# Lat: 37.1119, Long: -76.8959
# Predicted Label: 0.6132, Actual Label: 0.6154
#
# Lat: 23.6585, Long: -102.008
# Predicted Label: 0.7362, Actual Label: 0.7439
#
# Lat: 5.4679, Long: -74.6745
# Predicted Label: 0.6144, Actual Label: 0.6303
#
# Lat: 25.7878, Long: 106.4115
# Predicted Label: 0.5115, Actual Label: 0.4930
#
# Lat: 46.2985, Long: 125.2529
# Predicted Label: 0.4210, Actual Label: 0.4165
#
# Lat: 37.7919, Long: -105.5927
# Predicted Label: 0.6015, Actual Label: 0.6160
#
# Lat: 3.9015, Long: -76.2967
# Predicted Label: 0.6932, Actual Label: 0.6883
#
# Lat: 33.9096, Long: 117.3275
# Predicted Label: 0.5838, Actual Label: 0.5956
#
# Lat: -15.4027, Long: -43.8174
# Predicted Label: 0.7639, Actual Label: 0.7690
#
# Lat: 38.3797, Long: 117.5781
# Predicted Label: 0.6098, Actual Label: 0.6154
#
# Lat: -9.6802, Long: -40.6747
# Predicted Label: 0.7382, Actual Label: 0.7430
#
# Lat: -15.8183, Long: -43.4438
# Predicted Label: 0.7658, Actual Label: 0.7740
#
# Lat: 30.68, Long: -86.7805
# Predicted Label: 0.5254, Actual Label: 0.5325
#
# Lat: 21.8432, Long: -101.719
# Predicted Label: 0.7382, Actual Label: 0.7185
#
# Lat: 41.799, Long: 116.3316
# Predicted Label: 0.6025, Actual Label: 0.5916
#
# Lat: 21.3148, Long: 109.935
# Predicted Label: 0.5962, Actual Label: 0.6011
#
# Lat: 41.393, Long: -74.4657
# Predicted Label: 0.5308, Actual Label: 0.5373
#
# Lat: -9.7069, Long: -40.4767
# Predicted Label: 0.7330, Actual Label: 0.7330
#
# Lat: 26.556, Long: -104.127
# Predicted Label: 0.7461, Actual Label: 0.7468
#
# Lat: -15.2392, Long: -43.7303
# Predicted Label: 0.7740, Actual Label: 0.7843
#
# Lat: 29.871, Long: -82.723
# Predicted Label: 0.7243, Actual Label: 0.7024
#
# Lat: 38.498, Long: 117.627
# Predicted Label: 0.5909, Actual Label: 0.5776
#
# Lat: -21.846, Long: -41.1052
# Predicted Label: 0.7607, Actual Label: 0.7697
#
# Lat: 32.7414, Long: -101.6218
# Predicted Label: 0.4742, Actual Label: 0.4370
#
# Lat: -33.086, Long: -70.8862
# Predicted Label: 0.8469, Actual Label: 0.8607
#
# Lat: 36.551, Long: 107.199
# Predicted Label: 0.6647, Actual Label: 0.6548
#
# Lat: 32.952, Long: -101.737
# Predicted Label: 0.5481, Actual Label: 0.5598
#
# Lat: 22.763, Long: -102.5818
# Predicted Label: 0.8233, Actual Label: 0.8322
#
# Lat: 38.411, Long: 102.053
# Predicted Label: 0.7294, Actual Label: 0.7213
#
# Lat: 21.8942, Long: -102.076
# Predicted Label: 0.7890, Actual Label: 0.8000
#
# Lat: -32.4148, Long: 18.7379
# Predicted Label: 0.7525, Actual Label: 0.7622
#
# Lat: -16.5802, Long: -41.2315
# Predicted Label: 0.5969, Actual Label: 0.6104
#
# Lat: -5.2781, Long: -35.9505
# Predicted Label: 0.7366, Actual Label: 0.7300
#
# Lat: 41.2007, Long: 69.5141
# Predicted Label: 0.7260, Actual Label: 0.7148
#
# Lat: -15.9124, Long: -43.4818
# Predicted Label: 0.7640, Actual Label: 0.7721
#
# Lat: 24.0214, Long: -104.6587
# Predicted Label: 0.6291, Actual Label: 0.6505
#
# Lat: 35.4855, Long: 106.7037
# Predicted Label: 0.6400, Actual Label: 0.6429
#
# Lat: 35.033, Long: -117.338
# Predicted Label: 0.7007, Actual Label: 0.6667
#
# Lat: -4.8123, Long: -37.4517
# Predicted Label: 0.7427, Actual Label: 0.7468
#
# Lat: -18.6178, Long: -69.6062
# Predicted Label: 0.8910, Actual Label: 0.9301
#
# Lat: 28.3962, Long: -111.3836
# Predicted Label: 0.7491, Actual Label: 0.7385
#
# Lat: 28.551, Long: 108.3654
# Predicted Label: 0.5493, Actual Label: 0.5410
#
# Lat: -15.5271, Long: -46.8575
# Predicted Label: 0.7372, Actual Label: 0.7359
#
# Lat: -15.5483, Long: -46.6997
# Predicted Label: 0.7316, Actual Label: 0.7313
#
# Lat: 38.103, Long: 102.326
# Predicted Label: 0.7249, Actual Label: 0.7202
#
# Lat: 31.5481, Long: -99.1872
# Predicted Label: 0.5627, Actual Label: 0.5729
#
# Lat: 8.1198, Long: -1.0223
# Predicted Label: 0.3039, Actual Label: 0.2566
#
# Lat: 41.4132, Long: 114.3584
# Predicted Label: 0.6014, Actual Label: 0.6166
#
# Lat: 30.8276, Long: -81.5562
# Predicted Label: 0.5674, Actual Label: 0.5762
#
# Lat: 21.7638, Long: -102.215
# Predicted Label: 0.8082, Actual Label: 0.8185
#
# Lat: -17.1449, Long: 29.829
# Predicted Label: 0.7489, Actual Label: 0.7617
#
# Lat: 32.286, Long: -83.98
# Predicted Label: 0.5417, Actual Label: 0.5606
#
# Lat: 25.1321, Long: 105.2534
# Predicted Label: 0.5707, Actual Label: 0.5735
#
# Lat: 27.0728, Long: 104.3552
# Predicted Label: 0.5236, Actual Label: 0.5201
#
# Lat: -14.1511, Long: -42.4886
# Predicted Label: 0.7427, Actual Label: 0.7471
#
# Lat: 14.265, Long: 36.6189
# Predicted Label: 0.7995, Actual Label: 0.8258
#
# Lat: -4.7182, Long: -42.2792
# Predicted Label: 0.7370, Actual Label: 0.7425
#
# Lat: -15.9501, Long: -43.3301
# Predicted Label: 0.7230, Actual Label: 0.7194
#
# Lat: 41.9693, Long: 117.1853
# Predicted Label: 0.5829, Actual Label: 0.5976
#
# Lat: 29.7672, Long: -81.7775
# Predicted Label: 0.5685, Actual Label: 0.5871
#
# Lat: -9.8555, Long: -40.5434
# Predicted Label: 0.7433, Actual Label: 0.7414
#
# Lat: 41.1635, Long: 114.7211
# Predicted Label: 0.6142, Actual Label: 0.6087
#
# Lat: 6.2273, Long: -75.572
# Predicted Label: 0.7115, Actual Label: 0.7136
#
# Lat: 33.8815, Long: -83.2467
# Predicted Label: 0.7880, Actual Label: 0.7879
#
# Lat: 36.426, Long: -114.923
# Predicted Label: 0.4921, Actual Label: 0.4689
#
# Lat: 38.4815, Long: -118.498
# Predicted Label: 0.5193, Actual Label: 0.5176
#
# Lat: 22.6276, Long: 108.9833
# Predicted Label: 0.5758, Actual Label: 0.5742
#
# Lat: 19.324, Long: 110.132
# Predicted Label: 0.6530, Actual Label: 0.6613
#
# Lat: 9.5091, Long: 42.0393
# Predicted Label: 0.8053, Actual Label: 0.8330
#
# Lat: 37.3248, Long: 114.3006
# Predicted Label: 0.5944, Actual Label: 0.5905
#
# Lat: 36.4765, Long: -76.136
# Predicted Label: 0.7682, Actual Label: 0.7739
#
# Lat: 38.6935, Long: 100.3979
# Predicted Label: 0.7587, Actual Label: 0.7607
#
# Lat: 34.6892, Long: -118.3247
# Predicted Label: 0.7047, Actual Label: 0.6946
#
# Lat: 39.203, Long: 118.455
# Predicted Label: 0.6028, Actual Label: 0.5991
#
# Lat: 40.6013, Long: 114.5417
# Predicted Label: 0.6109, Actual Label: 0.6063
#
# Lat: 25.2392, Long: 114.4442
# Predicted Label: 0.5647, Actual Label: 0.5777
#
# Lat: -7.6013, Long: -45.1537
# Predicted Label: 0.7429, Actual Label: 0.7459
#
# Lat: 37.6537, Long: 103.2721
# Predicted Label: 0.7319, Actual Label: 0.7311
#
# Lat: 34.7321, Long: -118.3136
# Predicted Label: 0.6369, Actual Label: 0.6466
#
# Lat: 29.5693, Long: 114.0277
# Predicted Label: 0.6150, Actual Label: 0.6131
#
# Lat: -15.6251, Long: -46.1846
# Predicted Label: 0.7386, Actual Label: 0.7379
#
# Lat: 33.406, Long: 116.983
# Predicted Label: 0.4333, Actual Label: 0.4746
#
# Lat: 40.0957, Long: 114.1504
# Predicted Label: 0.6237, Actual Label: 0.6268
#
# Lat: 36.054, Long: 114.051
# Predicted Label: 0.4116, Actual Label: 0.3916
#
# Lat: -16.3401, Long: -43.6001
# Predicted Label: 0.7502, Actual Label: 0.7564
#
# Lat: 12.6122, Long: -7.9962
# Predicted Label: 0.8060, Actual Label: 0.8168
#
# Lat: 4.9844, Long: -75.6032
# Predicted Label: 0.7307, Actual Label: 0.7316
#
# Lat: 30.998, Long: 6.7665
# Predicted Label: 0.7510, Actual Label: 0.7528
#
# Lat: 26.8007, Long: 112.0848
# Predicted Label: 0.5487, Actual Label: 0.5384
#
# Lat: -14.7874, Long: -43.643
# Predicted Label: 0.7745, Actual Label: 0.7821
#
# Lat: 37.0164, Long: -79.0271
# Predicted Label: 0.4528, Actual Label: 0.4292
#
# Lat: 19.5357, Long: -70.0004
# Predicted Label: 0.6437, Actual Label: 0.6469
#
# Lat: 34.4083, Long: -116.8625
# Predicted Label: 0.6156, Actual Label: 0.6224
#
# Lat: 26.837, Long: 110.3585
# Predicted Label: 0.5436, Actual Label: 0.5393
#
# Lat: 31.2372, Long: 115.0782
# Predicted Label: 0.5612, Actual Label: 0.5542
#
# Lat: 33.6947, Long: -114.7397
# Predicted Label: 0.8085, Actual Label: 0.8054
#
# Lat: -17.2323, Long: -47.0855
# Predicted Label: 0.7403, Actual Label: 0.7416
#
# Lat: -13.2478, Long: -43.2667
# Predicted Label: 0.7874, Actual Label: 0.7949
#
# Lat: 10.4684, Long: -73.2586
# Predicted Label: 0.6623, Actual Label: 0.6564
#
# Lat: 6.4745, Long: -10.6482
# Predicted Label: 0.5825, Actual Label: 0.5846
#
# Lat: -23.8642, Long: -69.128
# Predicted Label: 0.8910, Actual Label: 0.9301
#
# Lat: -13.2549, Long: -43.3555
# Predicted Label: 0.7077, Actual Label: 0.6986
#
# Lat: 23.4729, Long: 108.0153
# Predicted Label: 0.5387, Actual Label: 0.5187
#
# Lat: 22.5501, Long: 108.1798
# Predicted Label: 0.3620, Actual Label: 0.3082
#
# Lat: 32.9774, Long: -113.4945
# Predicted Label: 0.6112, Actual Label: 0.6195
#
# Lat: 29.1779, Long: -95.7612
# Predicted Label: 0.5696, Actual Label: 0.5778
#
# Lat: 41.2149, Long: 116.6455
# Predicted Label: 0.3666, Actual Label: 0.4078
#
# Lat: 21.4716, Long: 110.2374
# Predicted Label: 0.5961, Actual Label: 0.6002
#
# Lat: 33.6725, Long: -114.75
# Predicted Label: 0.8063, Actual Label: 0.8082
#
# Lat: 43.444, Long: -116.333
# Predicted Label: 0.6324, Actual Label: 0.6365
#
# Lat: 48.7072, Long: -94.2511
# Predicted Label: 0.4613, Actual Label: 0.4365
#
# Lat: -17.2389, Long: -47.0486
# Predicted Label: 0.7495, Actual Label: 0.7524
#
# Lat: 31.903, Long: 112.6735
# Predicted Label: 0.5952, Actual Label: 0.5972
#
# Lat: 36.5788, Long: 107.3194
# Predicted Label: 0.6393, Actual Label: 0.6385
#
# Lat: 27.0782, Long: 112.3356
# Predicted Label: 0.5556, Actual Label: 0.5527
#
# Lat: -10.1161, Long: -45.2738
# Predicted Label: 0.7730, Actual Label: 0.7824
#
# Lat: -16.5349, Long: -50.177
# Predicted Label: 0.7348, Actual Label: 0.7359
#
# Lat: 9.2358, Long: -2.4518
# Predicted Label: 0.7587, Actual Label: 0.7681
#
# Lat: -15.1021, Long: -44.6459
# Predicted Label: 0.7486, Actual Label: 0.7461
#
# Lat: 31.4798, Long: 113.7674
# Predicted Label: 0.5689, Actual Label: 0.5562
#
# Lat: 20.4321, Long: -101.724
# Predicted Label: 0.7840, Actual Label: 0.7781
#
# Lat: 29.9934, Long: 112.7819
# Predicted Label: 0.5543, Actual Label: 0.5430
#
# Lat: -15.7088, Long: -45.9475
# Predicted Label: 0.7505, Actual Label: 0.7544
#
# Lat: 18.2794, Long: -70.3917
# Predicted Label: 0.7639, Actual Label: 0.7636
#
# Lat: 29.6082, Long: 114.4775
# Predicted Label: 0.5697, Actual Label: 0.5786
#
# Lat: 23.9904, Long: -104.658
# Predicted Label: 0.7729, Actual Label: 0.7862
#
# Lat: 35.1677, Long: -91.6603
# Predicted Label: 0.6027, Actual Label: 0.6144
#
# Lat: -16.1617, Long: -43.6377
# Predicted Label: 0.7385, Actual Label: 0.7393
#
# Lat: 26.7479, Long: 104.2593
# Predicted Label: 0.5555, Actual Label: 0.5572
#
# Lat: 35.0133, Long: -118.2698
# Predicted Label: 0.5075, Actual Label: 0.5024
#
# Lat: 24.624, Long: 110.6329
# Predicted Label: 0.5617, Actual Label: 0.5642
#
# Lat: -13.3227, Long: -43.2951
# Predicted Label: 0.7845, Actual Label: 0.7911
#
# Lat: 37.7666, Long: -86.478
# Predicted Label: 0.6999, Actual Label: 0.6905
#
# Lat: -8.3501, Long: -36.2401
# Predicted Label: 0.6308, Actual Label: 0.6389
#
# Lat: 19.7641, Long: -72.1975
# Predicted Label: 0.7471, Actual Label: 0.7377
#
# Lat: 26.2255, Long: 111.6245
# Predicted Label: 0.5362, Actual Label: 0.5259
#
# Lat: 31.9147, Long: -116.2632
# Predicted Label: 0.8192, Actual Label: 0.8249
#
# Lat: 40.7184, Long: -117.0614
# Predicted Label: 0.7283, Actual Label: 0.7218
#
# Lat: -53.1502, Long: -70.9174
# Predicted Label: 0.5958, Actual Label: 0.6131
#
# Lat: -4.8076, Long: -37.4433
# Predicted Label: 0.7394, Actual Label: 0.7430
#
# Lat: 29.4856, Long: -82.8435
# Predicted Label: 0.4747, Actual Label: 0.4719
#
# Lat: 42.5708, Long: -77.453
# Predicted Label: 0.4518, Actual Label: 0.4286
#
# Lat: -5.3156, Long: -39.5744
# Predicted Label: 0.6772, Actual Label: 0.6692
#
# Lat: 24.8, Long: 113.4761
# Predicted Label: 0.5432, Actual Label: 0.5466
#
# Lat: 31.878, Long: 113.2878
# Predicted Label: 0.5674, Actual Label: 0.5665
#
# Lat: 34.8634, Long: -116.8276
# Predicted Label: 0.7214, Actual Label: 0.7190
#
# Lat: -10.628, Long: -44.3818
# Predicted Label: 0.7436, Actual Label: 0.7454
#
# Lat: -31.7613, Long: -71.3188
# Predicted Label: 0.6603, Actual Label: 0.6427
#
# Lat: -18.8166, Long: -46.6906
# Predicted Label: 0.7132, Actual Label: 0.7077
#
# Lat: 35.2925, Long: -80.4975
# Predicted Label: 0.4899, Actual Label: 0.4861
#
# Lat: 34.5004, Long: -91.5526
# Predicted Label: 0.5384, Actual Label: 0.5341
#
# Lat: 41.0871, Long: 113.9635
# Predicted Label: 0.6392, Actual Label: 0.6393
#
# Lat: 33.6673, Long: 113.1115
# Predicted Label: 0.6079, Actual Label: 0.6169
#
# Lat: 40.1414, Long: 94.6678
# Predicted Label: 0.6970, Actual Label: 0.6634
#
# Lat: 43.0186, Long: -116.0071
# Predicted Label: 0.6734, Actual Label: 0.6665
#
# Lat: 35.9703, Long: -107.5631
# Predicted Label: 0.6717, Actual Label: 0.6531
#
# Lat: 38.598, Long: 117.417
# Predicted Label: 0.6180, Actual Label: 0.6154
#
# Lat: 35.7814, Long: -114.993
# Predicted Label: 0.7805, Actual Label: 0.7691
#
# Lat: 37.9275, Long: 102.6386
# Predicted Label: 0.6542, Actual Label: 0.6346
#
# Lat: 38.161, Long: 117.5369
# Predicted Label: 0.6510, Actual Label: 0.6508
#
# Lat: -16.3901, Long: -43.5901
# Predicted Label: 0.7136, Actual Label: 0.7078
#
# Lat: -14.8133, Long: -43.6291
# Predicted Label: 0.7734, Actual Label: 0.7813
#
# Lat: -15.2825, Long: -56.228
# Predicted Label: 0.7204, Actual Label: 0.7207
#
# Lat: 23.3719, Long: -109.468
# Predicted Label: 0.7555, Actual Label: 0.7596
#
# Lat: 34.7837, Long: -90.776
# Predicted Label: 0.5382, Actual Label: 0.5453
#
# Lat: -16.502, Long: -41.1679
# Predicted Label: 0.5978, Actual Label: 0.6123
#
# Lat: -16.464, Long: -53.1843
# Predicted Label: 0.7169, Actual Label: 0.7157
#
# Lat: -4.2916, Long: -41.8579
# Predicted Label: 0.7127, Actual Label: 0.7066
#
# Lat: 30.0419, Long: 113.4775
# Predicted Label: 0.5668, Actual Label: 0.5691
#
# Lat: 26.5821, Long: 111.8351
# Predicted Label: 0.5471, Actual Label: 0.5347
#
# Lat: 26.9668, Long: 103.8704
# Predicted Label: 0.5708, Actual Label: 0.5778
#
# Lat: 23.6585, Long: -102.008
# Predicted Label: 0.3100, Actual Label: 0.2920
#
# Lat: 36.408, Long: -114.908
# Predicted Label: 0.5040, Actual Label: 0.4915
#
# Lat: 23.017, Long: 114.496
# Predicted Label: 0.5571, Actual Label: 0.5632
#
# Lat: 39.2088, Long: 114.9923
# Predicted Label: 0.6466, Actual Label: 0.6423
#
# Lat: 19.7434, Long: -71.4528
# Predicted Label: 0.7381, Actual Label: 0.7438
#
# Lat: -18.6901, Long: -44.0801
# Predicted Label: 0.6619, Actual Label: 0.6665
#
# Lat: 34.8179, Long: 114.8131
# Predicted Label: 0.6282, Actual Label: 0.6367
#
# Lat: 36.5547, Long: -79.0286
# Predicted Label: 0.5338, Actual Label: 0.5363
#
# Lat: -7.3668, Long: -38.9747
# Predicted Label: 0.7081, Actual Label: 0.7025
#
# Lat: 33.2967, Long: 117.8971
# Predicted Label: 0.5920, Actual Label: 0.5908
#
# Lat: -10.7621, Long: -41.2701
# Predicted Label: 0.7133, Actual Label: 0.7117
#
# Lat: 40.7601, Long: 115.6339
# Predicted Label: 0.6097, Actual Label: 0.6092
#
# Lat: 25.3856, Long: 105.5754
# Predicted Label: 0.5583, Actual Label: 0.5637
#
# Lat: -18.8201, Long: -52.4301
# Predicted Label: 0.7042, Actual Label: 0.6993
#
# Lat: -29.8195, Long: 27.2472
# Predicted Label: 0.6883, Actual Label: 0.6987
#
# Lat: -4.9774, Long: -38.6373
# Predicted Label: 0.7596, Actual Label: 0.7667
#
# Lat: -20.625, Long: -51.2915
# Predicted Label: 0.7089, Actual Label: 0.6975
#
# Lat: 38.6071, Long: -75.8795
# Predicted Label: 0.5319, Actual Label: 0.5365
#
# Lat: 27.782, Long: -82.3905
# Predicted Label: 0.5448, Actual Label: 0.5534
#
# Lat: 19.5889, Long: -98.1134
# Predicted Label: 0.7707, Actual Label: 0.7888
#
# Lat: 26.8961, Long: 113.1902
# Predicted Label: 0.5509, Actual Label: 0.5528
#
# Lat: 24.678, Long: 106.4303
# Predicted Label: 0.5511, Actual Label: 0.5438
#
# Lat: 27.697, Long: 111.423
# Predicted Label: 0.5482, Actual Label: 0.5320
#
# Lat: 35.9106, Long: -80.8257
# Predicted Label: 0.5971, Actual Label: 0.6091
#
# Lat: 37.9333, Long: 115.6328
# Predicted Label: 0.6036, Actual Label: 0.6092
#
# Lat: 25.0425, Long: 105.2522
# Predicted Label: 0.5679, Actual Label: 0.5805
#
# Lat: 25.5098, Long: 105.0064
# Predicted Label: 0.5691, Actual Label: 0.5742
#
# Lat: 37.246, Long: -121.104
# Predicted Label: 0.6009, Actual Label: 0.6023
#
# Lat: 30.39, Long: -83.344
# Predicted Label: 0.7382, Actual Label: 0.7261
#
# Lat: 25.9305, Long: 105.4905
# Predicted Label: 0.5687, Actual Label: 0.5795
#
# Lat: 33.8055, Long: -115.3947
# Predicted Label: 0.8206, Actual Label: 0.8336
#
# Lat: -5.2429, Long: -38.0011
# Predicted Label: 0.7533, Actual Label: 0.7576
#
# Lat: 36.2168, Long: -119.8964
# Predicted Label: 0.5924, Actual Label: 0.6106
#
# Lat: 27.0307, Long: -80.5248
# Predicted Label: 0.4859, Actual Label: 0.4928
#
# Lat: 25.9198, Long: 105.357
# Predicted Label: 0.5559, Actual Label: 0.5643
#
# Lat: 28.7017, Long: -98.4434
# Predicted Label: 0.6755, Actual Label: 0.6634
#
# Lat: 46.4114, Long: 125.3286
# Predicted Label: 0.3835, Actual Label: 0.3572
#
# Lat: 38.732, Long: 115.057
# Predicted Label: 0.6309, Actual Label: 0.6330
#
# Lat: 41.3363, Long: 114.2136
# Predicted Label: 0.5990, Actual Label: 0.5933
#
# Lat: 39.0218, Long: -83.705
# Predicted Label: 0.4640, Actual Label: 0.4481
#
# Lat: 3.464, Long: -73.1386
# Predicted Label: 0.5304, Actual Label: 0.5317
#
# Lat: 15.857, Long: -16.224
# Predicted Label: 0.7776, Actual Label: 0.7960
#
# Lat: -6.753, Long: -38.8295
# Predicted Label: 0.7330, Actual Label: 0.7392
#
# Lat: 38.5977, Long: 114.4016
# Predicted Label: 0.6168, Actual Label: 0.6223
#
# Lat: 18.012, Long: -66.2739
# Predicted Label: 0.2965, Actual Label: 0.3000
#
# Lat: 39.7605, Long: 98.1227
# Predicted Label: 0.7786, Actual Label: 0.7589
#
# Lat: -16.5698, Long: -41.2468
# Predicted Label: 0.5854, Actual Label: 0.5977
#
# Lat: 27.2644, Long: 104.607
# Predicted Label: 0.5272, Actual Label: 0.5204
#
# Lat: -5.8529, Long: -36.6363
# Predicted Label: 0.7574, Actual Label: 0.7637
#
# Lat: 27.1657, Long: 18.5999
# Predicted Label: 0.7706, Actual Label: 0.7719
#
# Lat: 31.977, Long: -88.8876
# Predicted Label: 0.4664, Actual Label: 0.4432
#
# Lat: 32.6123, Long: -99.8208
# Predicted Label: 0.7418, Actual Label: 0.7342
#
# Lat: 5.8246, Long: -73.0318
# Predicted Label: 0.6932, Actual Label: 0.6883
#
# Lat: 39.8991, Long: 93.5166
# Predicted Label: 0.6354, Actual Label: 0.6362
#
# Lat: -12.4286, Long: -42.8207
# Predicted Label: 0.7881, Actual Label: 0.8001
#
# Lat: 18.4737, Long: -66.9382
# Predicted Label: 0.2525, Actual Label: 0.2182
#
# Lat: -4.824, Long: -37.4781
# Predicted Label: 0.7308, Actual Label: 0.7333
#
# Lat: 22.6099, Long: 111.6157
# Predicted Label: 0.5616, Actual Label: 0.5654
#
# Lat: 7.9497, Long: -3.9495
# Predicted Label: 0.6587, Actual Label: 0.6522
#
# Lat: -4.787, Long: -41.4263
# Predicted Label: 0.6834, Actual Label: 0.6902
#
# Lat: -15.6728, Long: -45.3832
# Predicted Label: 0.7582, Actual Label: 0.7626
#
# Lat: 21.8206, Long: 110.756
# Predicted Label: 0.5911, Actual Label: 0.5957
#
# Lat: 43.0174, Long: -74.253
# Predicted Label: 0.5138, Actual Label: 0.5152
#
# Lat: 29.3228, Long: 111.9304
# Predicted Label: 0.5241, Actual Label: 0.5119
#
# Lat: -8.2938, Long: -42.3565
# Predicted Label: 0.7460, Actual Label: 0.7522
#
# Lat: -9.3968, Long: -38.1468
# Predicted Label: 0.7044, Actual Label: 0.6982
#
# Lat: 32.345, Long: 117.3595
# Predicted Label: 0.5990, Actual Label: 0.5972
#
# Lat: -8.321, Long: -36.2433
# Predicted Label: 0.7368, Actual Label: 0.7348
#
# Lat: 23.995, Long: 109.9174
# Predicted Label: 0.5376, Actual Label: 0.5335
#
# Lat: -19.4701, Long: 29.7681
# Predicted Label: 0.7255, Actual Label: 0.7282
#
# Lat: -5.8761, Long: -36.5678
# Predicted Label: 0.7421, Actual Label: 0.7526
#
# Lat: 39.5446, Long: -87.972
# Predicted Label: 0.6744, Actual Label: 0.6700
#
# Lat: 32.8838, Long: -4.7101
# Predicted Label: 0.7651, Actual Label: 0.7722
#
# Lat: 33.7815, Long: -80.2323
# Predicted Label: 0.7412, Actual Label: 0.7376
#
# Lat: 38.81, Long: -95.035
# Predicted Label: 0.5347, Actual Label: 0.5436
#
# Lat: 38.278, Long: 117.0001
# Predicted Label: 0.5909, Actual Label: 0.5776
#
# Lat: -18.9721, Long: 27.4051
# Predicted Label: 0.8136, Actual Label: 0.8334
#
# Lat: 26.6995, Long: 104.1162
# Predicted Label: 0.5590, Actual Label: 0.5667
#
# Lat: 26.7016, Long: -81.1292
# Predicted Label: 0.5700, Actual Label: 0.5835
#
# Lat: -10.5594, Long: -44.4194
# Predicted Label: 0.7458, Actual Label: 0.7492
#
# Lat: 32.9706, Long: 117.1995
# Predicted Label: 0.5865, Actual Label: 0.5899
#
# Lat: 40.9888, Long: -76.7929
# Predicted Label: 0.7902, Actual Label: 0.7899
#
# Lat: -15.7528, Long: -45.9997
# Predicted Label: 0.7454, Actual Label: 0.7456
#
# Lat: -9.5635, Long: -40.4282
# Predicted Label: 0.7239, Actual Label: 0.7223
#
# Lat: -8.5459, Long: -45.2764
# Predicted Label: 0.7554, Actual Label: 0.7571
#
# Lat: 34.5123, Long: -117.4775
# Predicted Label: 0.4554, Actual Label: 0.4337
#
# Lat: 37.324, Long: 114.331
# Predicted Label: 0.6215, Actual Label: 0.6145
#
# Lat: -9.6812, Long: -40.7156
# Predicted Label: 0.7445, Actual Label: 0.7499
#
# Lat: -17.1901, Long: -46.6401
# Predicted Label: 0.7364, Actual Label: 0.7344
#
# Lat: -12.1478, Long: -44.7448
# Predicted Label: 0.7450, Actual Label: 0.7446
#
# Lat: 26.6926, Long: -81.325
# Predicted Label: 0.6138, Actual Label: 0.6230
#
# Lat: 36.9426, Long: -79.1928
# Predicted Label: 0.4677, Actual Label: 0.4647
#
# Lat: 23.0499, Long: 114.9627
# Predicted Label: 0.5624, Actual Label: 0.5703
#
# Lat: -15.6827, Long: -46.5618
# Predicted Label: 0.7470, Actual Label: 0.7484
#
# Lat: 44.1019, Long: -80.7494
# Predicted Label: 0.3782, Actual Label: 0.3307
#
# Lat: 32.1308, Long: 112.7666
# Predicted Label: 0.5698, Actual Label: 0.5772
#
# Lat: 18.5688, Long: -70.0975
# Predicted Label: 0.6463, Actual Label: 0.6448
#
# Lat: 30.6062, Long: 117.2936
# Predicted Label: 0.5695, Actual Label: 0.5774
#
# Lat: 30.4151, Long: -86.4233
# Predicted Label: 0.5877, Actual Label: 0.6012
#
# Lat: 42.719, Long: -90.701
# Predicted Label: 0.5791, Actual Label: 0.5979
#
# Lat: 31.634, Long: 116.344
# Predicted Label: 0.5685, Actual Label: 0.5604
#
# Lat: -4.7692, Long: -37.5015
# Predicted Label: 0.7390, Actual Label: 0.7431
#
# Lat: -4.8088, Long: -37.4791
# Predicted Label: 0.7424, Actual Label: 0.7477
#
# Lat: -35.0465, Long: -64.2568
# Predicted Label: 0.6336, Actual Label: 0.6304
#
# Lat: 22.7362, Long: 109.8871
# ...
#
# Lat: 22.9531, Long: 109.5285
# Predicted Label: 0.5450, Actual Label: 0.5258
#
# Lat: 11.8146, Long: 42.8453
# Predicted Label: 0.8535, Actual Label: 0.8900
#
# Lat: -14.9016, Long: -43.6206
# Predicted Label: 0.7796, Actual Label: 0.7892
#
# Lat: 8.3078, Long: 1.0103
# Predicted Label: 0.7470, Actual Label: 0.7497
#
# Lat: 33.7561, Long: 117.5613
# Predicted Label: 0.5909, Actual Label: 0.5901
#
# Lat: -14.8601, Long: -43.6052
# Predicted Label: 0.7675, Actual Label: 0.7721
#
# Lat: -5.8501, Long: -36.6601
# Predicted Label: 0.7427, Actual Label: 0.7533
#
# Lat: 41.8103, Long: 97.0288
# Predicted Label: 0.7654, Actual Label: 0.7723
#
# Lat: 8.7713, Long: 13.7804
# Predicted Label: 0.8172, Actual Label: 0.8558
#
# Lat: 9.5346, Long: -5.8284
# Predicted Label: 0.7317, Actual Label: 0.7416
#
# Lat: -11.9423, Long: -42.4234
# Predicted Label: 0.7075, Actual Label: 0.7022
#
# Lat: -16.3441, Long: -71.6046
# Predicted Label: 0.7566, Actual Label: 0.7537
#
# Lat: -19.774, Long: -51.4086
# Predicted Label: 0.7060, Actual Label: 0.7005
#
# Lat: 22.4078, Long: 112.3693
# Predicted Label: 0.5392, Actual Label: 0.5406
#
# Lat: -27.2998, Long: 27.1195
# Predicted Label: 0.7415, Actual Label: 0.7411
#
# Lat: -14.8844, Long: -49.509
# Predicted Label: 0.7216, Actual Label: 0.7222
#
# Lat: 32.1164, Long: -102.5283
# Predicted Label: 0.4477, Actual Label: 0.4537
#
# Lat: -19.0142, Long: 30.9065
# Predicted Label: 0.7768, Actual Label: 0.7967
#
# Lat: 22.0115, Long: 110.4196
# Predicted Label: 0.5819, Actual Label: 0.5901
#
# Lat: 8.6764, Long: 16.8515
# Predicted Label: 0.8021, Actual Label: 0.8264
#
# Lat: 38.6889, Long: 114.5095
# Predicted Label: 0.6424, Actual Label: 0.6446
#
# Lat: -17.8069, Long: 31.0764
# Predicted Label: 0.7312, Actual Label: 0.7487
#
# Lat: 42.8808, Long: -74.0951
# Predicted Label: 0.6025, Actual Label: 0.6148
#
# Lat: 41.7701, Long: -111.06
# Predicted Label: 0.7618, Actual Label: 0.7539
#
# Lat: 29.7135, Long: 32.3048
# Predicted Label: 0.7618, Actual Label: 0.7643
#
# Lat: -15.7934, Long: -45.8913
# Predicted Label: 0.7510, Actual Label: 0.7526
#
# Lat: -4.7962, Long: -37.4954
# Predicted Label: 0.7373, Actual Label: 0.7403
#
# Lat: 29.1364, Long: 113.884
# Predicted Label: 0.5556, Actual Label: 0.5485
#
# Lat: -33.4665, Long: -70.673
# Predicted Label: 0.9181, Actual Label: 0.9384
#
# Lat: -17.9312, Long: 25.8348
# Predicted Label: 0.7746, Actual Label: 0.7999
#
# Lat: 34.4234, Long: -80.0621
# Predicted Label: 0.6177, Actual Label: 0.6244
#
# Lat: 33.4164, Long: 113.2199
# Predicted Label: 0.5876, Actual Label: 0.5967
#
# Lat: 35.2637, Long: -77.799
# Predicted Label: 0.7762, Actual Label: 0.7814
#
# Lat: 38.2709, Long: 102.2997
# Predicted Label: 0.7282, Actual Label: 0.7243
#
# Lat: 38.5202, Long: 102.1926
# Predicted Label: 0.7277, Actual Label: 0.7009
#
# Lat: 25.3965, Long: 108.258
# Predicted Label: 0.5566, Actual Label: 0.5544
#
# Lat: 31.6454, Long: -2.0849
# Predicted Label: 0.8531, Actual Label: 0.8827
#
# Lat: -19.7803, Long: -50.8559
# Predicted Label: 0.7713, Actual Label: 0.7794
#
# Lat: 25.703, Long: 104.3699
# Predicted Label: 0.5439, Actual Label: 0.5431
#
# Lat: 22.7994, Long: 108.9245
# Predicted Label: 0.5876, Actual Label: 0.5871
#
# Lat: -3.9914, Long: -38.4222
# Predicted Label: 0.7281, Actual Label: 0.7290
#
# Lat: 23.0832, Long: 107.1394
# Predicted Label: 0.5291, Actual Label: 0.5353
#
# Lat: 31.619, Long: 113.8204
# Predicted Label: 0.5534, Actual Label: 0.5686
#
# Lat: -20.1911, Long: 32.6272
# Predicted Label: 0.7549, Actual Label: 0.7749
#
# Lat: 33.6801, Long: -114.73
# Predicted Label: 0.8222, Actual Label: 0.8248
#
# Lat: 32.4363, Long: 111.7564
# Predicted Label: 0.5654, Actual Label: 0.5663
#
# Lat: 19.5848, Long: -97.5922
# Predicted Label: 0.7532, Actual Label: 0.7688
#
# Lat: -17.2901, Long: -45.2201
# Predicted Label: 0.7378, Actual Label: 0.7381
#
# Lat: 33.7455, Long: 112.9103
# Predicted Label: 0.5870, Actual Label: 0.6016
#
# Lat: 5.7475, Long: -72.9996
# Predicted Label: 0.6411, Actual Label: 0.6481
#
# Lat: 35.9901, Long: -120.12
# Predicted Label: 0.7743, Actual Label: 0.7773
#
# Lat: -17.4842, Long: -44.7905
# Predicted Label: 0.7405, Actual Label: 0.7382
#
# Lat: 33.371, Long: -112.778
# Predicted Label: 0.6102, Actual Label: 0.6193
#
# Lat: -4.804, Long: -37.4784
# Predicted Label: 0.7355, Actual Label: 0.7377
#
# Lat: -34.267, Long: -70.7936
# Predicted Label: 0.7199, Actual Label: 0.6966
#
# Lat: -8.8943, Long: -37.9202
# Predicted Label: 0.7280, Actual Label: 0.7320
#
# Lat: 38.8955, Long: 100.8046
# Predicted Label: 0.7606, Actual Label: 0.7615
#
# Lat: 39.5631, Long: -77.7203
# Predicted Label: 0.4787, Actual Label: 0.4792
#
# Lat: -17.4201, Long: -44.9901
# Predicted Label: 0.7214, Actual Label: 0.7232
#
# Lat: -16.5111, Long: 28.7586
# Predicted Label: 0.7428, Actual Label: 0.7592
#
# Lat: 40.1434, Long: 94.6602
# Predicted Label: 0.7843, Actual Label: 0.7858
#
# Lat: 38.2999, Long: -84.3835
# Predicted Label: 0.5854, Actual Label: 0.6016
#
# Lat: 32.8927, Long: 115.809
# Predicted Label: 0.5850, Actual Label: 0.5780
#
# Lat: 35.8563, Long: -119.0684
# Predicted Label: 0.7441, Actual Label: 0.7457
#
# Lat: -9.6778, Long: -40.7129
# Predicted Label: 0.7528, Actual Label: 0.7583
#
# Lat: 38.846, Long: 100.949
# Predicted Label: 0.7655, Actual Label: 0.7700
#
# Lat: -15.7272, Long: -45.9473
# Predicted Label: 0.7530, Actual Label: 0.7559
#
# Lat: 35.8829, Long: -78.155
# Predicted Label: 0.8047, Actual Label: 0.8076
#
# Lat: 39.7627, Long: 98.1343
# Predicted Label: 0.7010, Actual Label: 0.6868
#
# Lat: 42.9583, Long: -77.195
# Predicted Label: 0.4643, Actual Label: 0.4459
#
# Lat: 23.5835, Long: 113.0357
# Predicted Label: 0.5547, Actual Label: 0.5518
#
# Lat: -0.3043, Long: 15.4995
# Predicted Label: 0.6146, Actual Label: 0.6243
#
# Lat: 36.6922, Long: -76.5786
# Predicted Label: 0.5122, Actual Label: 0.5114
#
# Lat: 36.533, Long: -78.105
# Predicted Label: 0.4357, Actual Label: 0.4259
#
# Lat: 23.1358, Long: 113.1983
# Predicted Label: 0.5446, Actual Label: 0.5501
#
# Lat: -14.7849, Long: -43.5928
# Predicted Label: 0.7895, Actual Label: 0.8012
#
# Lat: 31.1771, Long: 117.9193
# Predicted Label: 0.5581, Actual Label: 0.5566
#
# Lat: -7.9854, Long: -38.2957
# Predicted Label: 0.7811, Actual Label: 0.7921
#
# Lat: 45.715, Long: -87.135
# Predicted Label: 0.6008, Actual Label: 0.6154
#
# Lat: 8.1198, Long: -1.0223
# Predicted Label: 0.7541, Actual Label: 0.7552
#
# Lat: 36.8162, Long: -77.4724
# Predicted Label: 0.5211, Actual Label: 0.5259
#
# Lat: 24.1083, Long: 109.709
# Predicted Label: 0.5329, Actual Label: 0.5249
#
# Lat: -17.2001, Long: -46.6001
# Predicted Label: 0.7486, Actual Label: 0.7477
#
# Lat: 30.8246, Long: -96.9755
# Predicted Label: 0.6347, Actual Label: 0.6386
#
# Lat: -13.2424, Long: -56.042
# Predicted Label: 0.7115, Actual Label: 0.7068
#
# Lat: 25.569, Long: 106.439
# Predicted Label: 0.5383, Actual Label: 0.5378
#
# Lat: 25.9294, Long: 112.5751
# Predicted Label: 0.5512, Actual Label: 0.5556
#
# Lat: 30.808, Long: 116.984
# Predicted Label: 0.5643, Actual Label: 0.5657
#
# Lat: -29.4144, Long: -66.8115
# Predicted Label: 0.7141, Actual Label: 0.7061
#
# Lat: 27.6398, Long: -81.6544
# Predicted Label: 0.4988, Actual Label: 0.4759
#
# Lat: -15.5336, Long: -46.8648
# Predicted Label: 0.7303, Actual Label: 0.7302
#
# Lat: 38.7087, Long: 114.8058
# Predicted Label: 0.6244, Actual Label: 0.6236
#
# Lat: -8.5504, Long: -42.2927
# Predicted Label: 0.7476, Actual Label: 0.7508
#
# Lat: 22.1683, Long: 109.9501
# Predicted Label: 0.5654, Actual Label: 0.5628
#
# Lat: 10.8891, Long: -74.9774
# Predicted Label: 0.5902, Actual Label: 0.6128
#
# Lat: 32.7273, Long: -111.5866
# Predicted Label: 0.4749, Actual Label: 0.4749
#
# Lat: -16.5497, Long: -41.2201
# Predicted Label: 0.5899, Actual Label: 0.6022
#
# Lat: -24.0915, Long: -66.7248
# Predicted Label: 0.7787, Actual Label: 0.7813
#
# Lat: -17.4101, Long: -45.0301
# Predicted Label: 0.7187, Actual Label: 0.7162
#
# Lat: 32.8353, Long: 110.7495
# Predicted Label: 0.5736, Actual Label: 0.5657
#
# Lat: 35.0199, Long: -118.2879
# Predicted Label: 0.7913, Actual Label: 0.8000
#
# Lat: -17.8822, Long: 30.6675
# Predicted Label: 0.7186, Actual Label: 0.7213
#
# Lat: 38.5008, Long: -113.03
# Predicted Label: 0.6852, Actual Label: 0.6745
#
# Lat: 32.7933, Long: -115.572
# Predicted Label: 0.7002, Actual Label: 0.6916
#
# Lat: 25.3367, Long: 105.4761
# Predicted Label: 0.5626, Actual Label: 0.5619
#
# Lat: -15.1518, Long: -44.6957
# Predicted Label: 0.7421, Actual Label: 0.7386
#
# Lat: 19.4798, Long: -70.7184
# Predicted Label: 0.5938, Actual Label: 0.6143
#
# Lat: 26.254, Long: 29.2675
# Predicted Label: 0.7548, Actual Label: 0.7607
#
# Lat: 23.8737, Long: 113.6745
# Predicted Label: 0.5549, Actual Label: 0.5618
#
# Lat: 26.6123, Long: 111.4851
# Predicted Label: 0.5480, Actual Label: 0.5362
#
# Lat: 26.7491, Long: -81.1921
# Predicted Label: 0.4582, Actual Label: 0.4342
#
# Lat: -4.737, Long: -42.1347
# Predicted Label: 0.7298, Actual Label: 0.7324
#
# Lat: 24.3624, Long: 114.5626
# Predicted Label: 0.6060, Actual Label: 0.6151
#
# Lat: 38.005, Long: -78.046
# Predicted Label: 0.7770, Actual Label: 0.7826
#
# Lat: 35.387, Long: -81.029
# Predicted Label: 0.5929, Actual Label: 0.6083
#
# Lat: 37.04, Long: -78.58
# Predicted Label: 0.7132, Actual Label: 0.7039
#
# Lat: 38.023, Long: -77.972
# Predicted Label: 0.4791, Actual Label: 0.4658
#
# Lat: -8.8673, Long: -38.2409
# Predicted Label: 0.7204, Actual Label: 0.7190
#
# Lat: 36.787, Long: -110.24
# Predicted Label: 0.6233, Actual Label: 0.6367
#
# Lat: -16.4653, Long: -53.1727
# Predicted Label: 0.7151, Actual Label: 0.7134
#
# Lat: -32.9951, Long: -71.1851
# Predicted Label: 0.7067, Actual Label: 0.6822
#
# Lat: -23.8642, Long: -69.128
# Predicted Label: 0.9289, Actual Label: 0.9663
#
# Lat: 26.936, Long: 111.844
# Predicted Label: 0.5581, Actual Label: 0.5660
#
# Lat: 24.0677, Long: 32.8959
# Predicted Label: 0.9120, Actual Label: 0.9532
#
# Lat: -8.2803, Long: -42.1375
# Predicted Label: 0.7271, Actual Label: 0.7275
#
# Lat: 33.1238, Long: -80.8425
# Predicted Label: 0.7779, Actual Label: 0.7766
#
# Lat: -4.7159, Long: -42.3581
# Predicted Label: 0.7496, Actual Label: 0.7560
#
# Lat: 26.4835, Long: -81.4677
# Predicted Label: 0.5099, Actual Label: 0.5207
#
# Lat: 8.8746, Long: -79.8126
# Predicted Label: 0.5924, Actual Label: 0.6199
#
# Lat: 5.9763, Long: -74.5873
# Predicted Label: 0.6170, Actual Label: 0.6286
#
# Lat: -18.2119, Long: -45.9526
# Predicted Label: 0.7313, Actual Label: 0.7295
#
# Lat: 33.3061, Long: 114.4238
# Predicted Label: 0.6198, Actual Label: 0.6240
#
# Lat: 32.5873, Long: 3.7314
# Predicted Label: 0.7788, Actual Label: 0.7774
#
# Lat: 38.9036, Long: 117.1607
# Predicted Label: 0.6080, Actual Label: 0.6043
#
# Lat: 31.7373, Long: 118.0959
# Predicted Label: 0.5605, Actual Label: 0.5590
#
# Lat: -10.5901, Long: -44.4501
# Predicted Label: 0.7462, Actual Label: 0.7485
#
# Lat: 38.401, Long: 114.039
# Predicted Label: 0.6353, Actual Label: 0.6453
#
# Lat: -9.8801, Long: -37.9101
# Predicted Label: 0.7469, Actual Label: 0.7510
#
# Lat: 25.9512, Long: 105.9779
# Predicted Label: 0.5489, Actual Label: 0.5493
#
# Lat: -8.2731, Long: -42.1079
# Predicted Label: 0.7583, Actual Label: 0.7673
#
# Lat: 46.18, Long: 125.0789
# Predicted Label: 0.4653, Actual Label: 0.4584
#
# Lat: 35.5742, Long: -88.9266
# Predicted Label: 0.5362, Actual Label: 0.5520
#
# Lat: 37.3566, Long: 115.4128
# Predicted Label: 0.6109, Actual Label: 0.6146
#
# Lat: 21.3501, Long: 109.8208
# Predicted Label: 0.6065, Actual Label: 0.6154
#
# Lat: 38.0551, Long: 115.7006
# Predicted Label: 0.6145, Actual Label: 0.6194
#
# Lat: 4.0999, Long: -72.9088
# Predicted Label: 0.5958, Actual Label: 0.6131
#
# Lat: 43.2921, Long: -78.5686
# Predicted Label: 0.7764, Actual Label: 0.7774
#
# Lat: 32.624, Long: -116.175
# Predicted Label: 0.2819, Actual Label: 0.2763
#
# Lat: 19.6201, Long: -99.786
# Predicted Label: 0.7262, Actual Label: 0.7338
#
# Lat: 40.1041, Long: -119.8883
# Predicted Label: 0.5101, Actual Label: 0.5120
#
# Lat: 50.7402, Long: -111.3714
# Predicted Label: 0.3730, Actual Label: 0.3673
#
# Lat: 37.8067, Long: -117.642
# Predicted Label: 0.6675, Actual Label: 0.6659
#
# Lat: -14.8618, Long: -43.5979
# Predicted Label: 0.7802, Actual Label: 0.7894
#
# Lat: 29.9427, Long: 115.6311
# Predicted Label: 0.6209, Actual Label: 0.6394
#
# Lat: 31.7104, Long: 116.8369
# Predicted Label: 0.6004, Actual Label: 0.6062
#
# Lat: 34.8634, Long: -116.888
# Predicted Label: 0.7642, Actual Label: 0.7653
#
# Lat: -8.0834, Long: -39.3555
# Predicted Label: 0.7108, Actual Label: 0.7090
#
# Lat: -8.8016, Long: -38.2476
# Predicted Label: 0.7345, Actual Label: 0.7375
#
# Lat: 49.8159, Long: -111.543
# Predicted Label: 0.4758, Actual Label: 0.4693
#
# Lat: 35.7511, Long: 114.2934
# Predicted Label: 0.6265, Actual Label: 0.6367
#
# Lat: 31.9141, Long: -96.4135
# Predicted Label: 0.6143, Actual Label: 0.6179
#
# Lat: 40.4552, Long: 115.7599
# Predicted Label: 0.6137, Actual Label: 0.6021
#
# Lat: 31.029, Long: 117.2994
# Predicted Label: 0.5965, Actual Label: 0.6015
#
# Lat: 27.215, Long: 105.7449
# Predicted Label: 0.5705, Actual Label: 0.5709
#
# Lat: -8.7698, Long: -38.2577
# Predicted Label: 0.7349, Actual Label: 0.7382
#
# Lat: -25.5748, Long: 26.0718
# Predicted Label: 0.7546, Actual Label: 0.7619
#
# Lat: 35.7822, Long: -114.9754
# Predicted Label: 0.7757, Actual Label: 0.7649
#
# Lat: -3.6836, Long: -38.8242
# Predicted Label: 0.6909, Actual Label: 0.6796
#
# Lat: -11.5419, Long: 18.1937
# Predicted Label: 0.7887, Actual Label: 0.8186
#
# Lat: 40.596, Long: -108.846
# Predicted Label: 0.4633, Actual Label: 0.4913
#
# Lat: 34.3433, Long: 3.1696
# Predicted Label: 0.7092, Actual Label: 0.7096
#
# Lat: -4.7561, Long: -37.5089
# Predicted Label: 0.7393, Actual Label: 0.7427
#
# Lat: 30.9602, Long: -103.3067
# Predicted Label: 0.7695, Actual Label: 0.7719
#
# Lat: 37.367, Long: -121.149
# Predicted Label: 0.7405, Actual Label: 0.7312
#
# Lat: 25.5947, Long: 105.3868
# Predicted Label: 0.5437, Actual Label: 0.5474
#
# Lat: 8.4388, Long: 8.2383
# Predicted Label: 0.7467, Actual Label: 0.7607
#
# Lat: -4.7311, Long: -37.4908
# Predicted Label: 0.7360, Actual Label: 0.7389
#
# Lat: 24.403, Long: 32.716
# Predicted Label: 0.9098, Actual Label: 0.9505
#
# Lat: 35.5219, Long: -76.6637
# Predicted Label: 0.5410, Actual Label: 0.5561
#
# Lat: 22.7654, Long: 111.7469
# Predicted Label: 0.5553, Actual Label: 0.5505
#
# Lat: 22.7069, Long: 110.3503
# Predicted Label: 0.5375, Actual Label: 0.5340
#
# Lat: -6.9391, Long: -37.0834
# Predicted Label: 0.7654, Actual Label: 0.7819
#
# Lat: 42.4517, Long: -73.8928
# Predicted Label: 0.4513, Actual Label: 0.4320
#
# Lat: 29.8941, Long: -97.2705
# Predicted Label: 0.6113, Actual Label: 0.6227
#
# Lat: 32.7777, Long: 117.6071
# Predicted Label: 0.5921, Actual Label: 0.5903
#
# Lat: 34.7803, Long: -98.2923
# Predicted Label: 0.4686, Actual Label: 0.4618
#
# Lat: 35.0394, Long: 9.4851
# Predicted Label: 0.7144, Actual Label: 0.7129
#
# Lat: 28.3495, Long: -111.3413
# Predicted Label: 0.7770, Actual Label: 0.7921
#
# Lat: 38.2605, Long: 114.186
# Predicted Label: 0.6213, Actual Label: 0.6267
#
# Lat: 29.1153, Long: 32.6598
# Predicted Label: 0.3454, Actual Label: 0.3293
#
# Lat: -16.4912, Long: -41.1706
# Predicted Label: 0.5875, Actual Label: 0.6020
#
# Lat: 23.3985, Long: 114.5985
# Predicted Label: 0.5871, Actual Label: 0.5948
#
# Lat: -12.047, Long: -45.069
# Predicted Label: 0.7646, Actual Label: 0.7692
#
# Lat: -16.4955, Long: -41.1739
# Predicted Label: 0.5998, Actual Label: 0.6132
#
# Lat: 33.4664, Long: -114.7936
# Predicted Label: 0.8111, Actual Label: 0.8130
#
# Lat: 35.894, Long: -78.149
# Predicted Label: 0.5720, Actual Label: 0.5864
#
# Lat: 25.9688, Long: 105.4422
# Predicted Label: 0.5535, Actual Label: 0.5589
#
# Lat: 32.827, Long: 117.6121
# Predicted Label: 0.5866, Actual Label: 0.5871
#
# Lat: -6.377, Long: -38.8579
# Predicted Label: 0.7431, Actual Label: 0.7509
#
# Lat: -16.1775, Long: -43.555
# Predicted Label: 0.7415, Actual Label: 0.7437
#
# Lat: 29.0365, Long: -110.987
# Predicted Label: 0.7004, Actual Label: 0.6943
#
# Lat: -16.4849, Long: -41.146
# Predicted Label: 0.5864, Actual Label: 0.6011
#
# Lat: -15.5149, Long: -47.4067
# Predicted Label: 0.5387, Actual Label: 0.5298
#
# Lat: 34.8597, Long: 4.2026
# Predicted Label: 0.7070, Actual Label: 0.7031
#
# Lat: -17.3001, Long: -45.2201
# Predicted Label: 0.6333, Actual Label: 0.6387
#
# Lat: -16.2301, Long: -43.5153
# Predicted Label: 0.5834, Actual Label: 0.6042
#
# Lat: 20.6123, Long: -103.5312
# Predicted Label: 0.5546, Actual Label: 0.5622
#
# Lat: -10.7914, Long: -41.2521
# Predicted Label: 0.7387, Actual Label: 0.7351
#
# Lat: 26.823, Long: 111.6976
# Predicted Label: 0.7464, Actual Label: 0.7524
#
# Lat: -23.1014, Long: -70.4687
# Predicted Label: 0.5450, Actual Label: 0.5258
#
# Lat: 24.9059, Long: 113.5454
# Predicted Label: 0.7529, Actual Label: 0.7620
